# %% [markdown]
# # RFC 호출

# %%
from pyrfc import Connection

# Establish the connection
conn = Connection(
    user="IF_RFC01",
    passwd="3002RFC01",
    ashost="172.17.0.150",  # Application server host
    sysnr="00",  # System number
    client="100",  # Client number
    lang="KO"  # Language
)

# Define the input parameters for the function call
input_parameters = {
    'I_VKONT': '110462632',
    'I_GUBUN': '1'
}

# Call the RFC function
try:
    result = conn.call('ZBI_MS_GOJI_LIST', I_VKONT='110462632', I_GUBUN='1')
    print("Result from ZBI_MS_GOJI_LIST:")
    print(result)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Result from ZBI_MS_GOJI_LIST:
# ...

# %%
from pyrfc import Connection

input_parameters = {'I_VKONTO': '000305476789'}
# num = '04'
name = 'ZPM_USERSAFE_03_AI'
rfc_user="IF_RFC01"
rfc_passwd="3002RFC01"
conn_operate = Connection(
    user="IF_RFC01", 
    passwd="3002RFC01", 
    mshost="vhsmyepocs.tyo2.hec.samchully.co.kr",
    msserv="3601",# Message server port (default is 3600)
    group="SCLIF",# Logon group 
    r3name="EPO",# SAP system ID 
    client="100",# Client number 
    lang="KO"# Language
)

rfc_conn = Connection(
    user=rfc_user,
    passwd=rfc_passwd,
    ashost="172.17.0.150",  # Application server host
    sysnr="00",  # System number
    client="100",  # Client number
    lang="KO"  # Language
)

result = rfc_conn.call(name, **input_parameters)
print(result)
# Out:
# {'E_RETCO': 'S', 'E_RETMSG': '점검자원 전송성공!.', 'E_SIGN': '', 'ET_TAB1': [{'CHK_YYMM': '202205', 'SCR_CHK_CLF': '1', 'CHK_CLF': '1', 'DDANJI': '000094704', 'HAUS': '172430', 'VSTELLE': '0502072570', 'ANLAGE': '6100845539', 'REGIOGROUP': '20M1', 'ZZSTATUS': '2', 'BEF_CHK_DAT': '20211105', 'BEF_CHKER_NO': 'U16233', 'BEF_FITN_YN': 'Y', 'SPCFS_YN': '', 'FC_INST_YN': '', 'GALM_INST_YN': '', 'GCB_INST_YN': '', 'CO_INST_YN': '', 'MICOM_INST_YN': '', 'FITN_YN': 'Y', 'SCHKER_NO': 'U08546', 'UCHK_RSN': '', 'SCR_MGR_NO': '김재광', 'SCR_MGR_CLF': '01', 'CHK_YN': 'Y', 'RECHK_DATE': '', 'UNFITN_ETC_RSN': '', 'CHK_DAT': '20220502', 'UPDATE_YN': '', 'DN_DATE': '', 'UP_DATE': '20220502', 'AKLASSE': 'LRH1', 'LIMIT_TIME': '3', 'UP_MTHD': '1', 'DN_MTHD': '1', 'BEF_UNFITN_RESC': '', 'SCR_TEL_NO': '01086450250', 'EDIT_DAT': '20220421', 'EDIT_EMP_COD': 'SCLBC01', 'MODF_DAT': '20220502', 'MODF_EMP_COD': 'IF_RFC01', 'CHK_GRD_COD': '02', 'UNFITN_GRD': '', 'MNG_GRD_COD': '02', 'ANLART': '', 'ZZFSUPDATE': '', 'ZZVALVE
# ...

# %%
# ZCS_GOJI_TYPE_INFO
# ZPM_USERSAFE_03_AI
from pyrfc import Connection
import pandas as pd
T_input = {
    'ADATSOLL': ['20241209'],
    'V_ZWSTAND2': ['100']
}
T_input = ['20241209', '100']
input_parameters = {'I_VKONT': '106800233', 'T_INPUT': T_input}
name = 'ZBI_TALK_COST_SIMULATION'
rfc_user="IF_RFC01"
rfc_passwd="3002RFC01"
rfc_conn = Connection(
    user=rfc_user,
    passwd=rfc_passwd,
    ashost="vhsmyepqci.tyo2.hec.samchully.co.kr",  # Application server host
    sysnr="00",  # System number
    client="100",  # Client number
    lang="KO"  # Language
)

result = rfc_conn.call(name, **input_parameters)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ABAPRuntimeError                          Traceback (most recent call last)
# Cell In[95], line 23
#      13 rfc_passwd="3002RFC01"
#      14 rfc_conn = Connection(
#      15     user=rfc_user,
#      16     passwd=rfc_passwd,
#    (...)
#      20     lang="KO"  # Language
#      21 )
# ---> 23 result = rfc_conn.call(name, **input_parameters)
#      24 print(result)
#
# File src/pyrfc/_cyrfc.pyx:937, in pyrfc._cyrfc.Connection.call()
#
# File src/pyrfc/_cyrfc.pyx:710, in pyrfc._cyrfc.Connection._error()
#
# ABAPRuntimeError: 4 (rc=4): key=01  .  . is not a valid date, message=01  .  . is not a valid date [MSG: class=HRPAYDE_REUSE, type=E, number=010, v1-4:=01  .  .;;;]

# %% [markdown]
# # DB 테이블 생성

# %% [markdown]
# ## 로그 테이블 생성

# %%
from thanosql import ThanoSQL
import psycopg2
# client = ThanoSQL(
#     api_token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ3b3Jrc3BhY2VfaWQiOjEsImV4cCI6OTIyMzM3MTk3NDcxOTE3OTAwMCwidG9rZW5faWQiOiI3MmI3Yjk1YXNmZTMzOTQyODlhMyJ9.QI_8riETPk7b3a8zGaiLckU4a9pSRzCcKxHI-pSvTUY",
#     engine_url="http://gateway:8000"
# )
connection = psycopg2.connect(host='18.119.33.153', dbname='default_database', user='thanosql_user', password='thanosql', port=8821)
cursor = connection.cursor()
query = """
        CREATE TABLE samchully_log(
            session_id TEXT,  -- 세션 ID, 기본 키
            message_id TEXT NOT NULL,     -- 메시지 ID
            question TEXT,                  -- 질문
            tag TEXT,                    -- 태그
            .similarty_search

            query TEXT,  
            RDB TEXT,                      -- RDB(단가표)
            RAG TEXT [],                    -- RAG(Retrieval 자료)
            RFC TEXT,                      -- RFC 함수 결과
            response TEXT,                   -- 응답
            history TEXT [],                 -- 이전 질문 및 응답 (배열 형태)
            validate_intention TEXT,         -- new vs continue vs general
            validate_additional TEXT,     -- continue + 추가로 데이터 필요한지 yes/no
            validate_tag TEXT,            -- 태그 유효성
            validate_rdb BOOLEAN,            -- RDB 유효성
            validate_rag BOOLEAN,            -- RAG 유효성
            validate_rfc BOOLEAN           -- RFC 유효성
        );
    """
# query = "SELECT * FROM samchully_log;"
# query = "DROP TABLE samchully_log;"
cursor.execute(query)
# result = cursor.fetchall()
# for i in result:
#     print(i)
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# ## 피드백 테이블

# %%
from thanosql import ThanoSQL

client = ThanoSQL(
    api_token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ3b3Jrc3BhY2VfaWQiOjEsImV4cCI6OTIyMzM3MTk3NDcxOTE3OTAwMCwidG9rZW5faWQiOiI3MmI3Yjk1YXNmZTMzOTQyODlhMyJ9.QI_8riETPk7b3a8zGaiLckU4a9pSRzCcKxHI-pSvTUY",
    engine_url="http://gateway:8000"
)

client.table.list()
# Out:
# [Table({
#      "name": "acpt",
#      "table_schema": "hmall",
#      "columns": null,
#      "constraints": null,
#      "service": "<thanosql.resources._table.TableService object at 0x7d4198bd9150>"
#  }),
#  Table({
#      "name": "feedback",
#      "table_schema": "public",
#      "columns": null,
#      "constraints": null,
#      "service": "<thanosql.resources._table.TableService object at 0x7d4198bd9150>"
#  }),
#  Table({
#      "name": "langchain_pg_collection",
#      "table_schema": "public",
#      "columns": null,
#      "constraints": null,
#      "service": "<thanosql.resources._table.TableService object at 0x7d4198bd9150>"
#  }),
#  Table({
#      "name": "langchain_pg_embedding",
#      "table_schema": "public",
#      "columns": null,
#      "constraints": null,
#      "service": "<thanosql.resources._table.TableService object at 0x7d4198bd9150>"
#  }),
#  Table({
#      "name": "rfc_info",
#      "table_schema": "public",
#      "columns": null,
# ...

# %%
client.query.execute("SELECT * FROM samchully_log")
# Out:
# QueryLog({
#     "query_id": "query-1cfa23ea-35e6-4af7-9e74-b20ce5b4d60e",
#     "statement_type": "SELECT",
#     "start_time": "2024-12-11T04:30:15.134954",
#     "end_time": "2024-12-11T04:30:15.181799",
#     "query": "SELECT * FROM samchully_log",
#     "referer": "API Request",
#     "state": "COMPLETE",
#     "destination_table_name": "table43d30f77a70a4950991fe4e6333fac5b",
#     "destination_schema": "qm",
#     "error_result": null,
#     "created_at": "2024-12-11T04:30:15.130538",
#     "records": {
#         "data": [
#             {
#                 "session_id": "1733891371001",
#                 "message_id": "7iGqTHL",
#                 "question": "가스요금은 어떤 수납방법이 있나요?",
#                 "tag": [
#                     "납부방법문의"
#                 ],
#                 "query": null,
# ...
